# %%
import pickle

# Cargar el archivo pickle
with open('/home/dsg/VORTEX_FINAL/PRODUCTION/models/20250227_VdHSpecific.pkl', 'rb') as f:
    data = pickle.load(f)

# Examinar el tipo de objeto
print(f"Tipo de objeto: {type(data)}")

# Ver información básica del objeto
print(f"Representación del objeto: {repr(data)}")

# Si es un diccionario, puedes ver sus claves
if isinstance(data, dict):
    print(f"Claves en el diccionario: {data.keys()}")

# Si es una lista o array, ver su tamaño
import numpy as np
if isinstance(data, (list, np.ndarray)):
    print(f"Longitud/forma: {len(data) if isinstance(data, list) else data.shape}")

# Si es un modelo de scikit-learn, examinar sus atributos
if hasattr(data, 'get_params'):
    print(f"Parámetros del modelo: {data.get_params()}")
# Out:
# Tipo de objeto: <class 'numpy.ndarray'>
# Representación del objeto: array(['CT', 'PCM', 'PDLC'], dtype=object)
# Longitud/forma: (3,)

# %%
from pycaret.classification import load_model
model = load_model('/home/dsg/VORTEX_FINAL/PRODUCTION/models/20250227_VdHSpecific')
model
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=Memory(location=None),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(include=['Al', 'Si', 'P', 'S', 'Cl', 'K',
#                                              'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co',
#                                              'Ni', 'Cu', 'Zn', 'As', 'Rb', 'Sr',
#                                              'Zr'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator',
#                  CalibratedClassifierCV(cv=5,
#                                         estimator=RandomForestClassifier(class_weight='balanced',
# ...
